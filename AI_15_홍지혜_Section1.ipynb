# %% [markdown]
# <a href="https://colab.research.google.com/github/Jihyesh/codestates_projects_section1/blob/main/AI_15_%ED%99%8D%EC%A7%80%ED%98%9C_Section1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-502549aa-905c-4462-8c46-92e670895ef0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-502549aa-905c-4462-8c46-92e670895ef0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving vgames2.csv to vgames2.csv

# %%
df = pd.read_csv('vgames2.csv')
df.head()
# Out:
#    Unnamed: 0                                            Name Platform  \
# 0           1                    Candace Kane's Candy Factory       DS
# 1           2                                  The Munchables      Wii
# 2           3  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP
# 3           4                Deal or No Deal: Special Edition       DS
# 4           5       Ben 10 Ultimate Alien: Cosmic Destruction      PS3
#
#      Year      Genre           Publisher NA_Sales EU_Sales JP_Sales  \
# 0  2008.0     Action           Destineer     0.04        0        0
# 1  2009.0     Action  Namco Bandai Games     0.17        0        0
# 2  2010.0  Adventure           Alchemist        0        0     0.02
# 3  2010.0       Misc           Zoo Games     0.04        0        0
# 4  2010.0   Platform         D3Publisher     0.12     0.09        0
#
#   Other_Sales
# 0           0
# 1        0.01
# 2           0
# 3           0
# 4        0.04

# %% [markdown]
# ##Mission
# <font color='blue'>비데이터 직군</font>의 청자에게 데이터를 기반으로 위의 주제에 대해 설명하는 영상 제출
# - **지역에 따라서 선호하는 게임 장르가 다를까** 라는 질문에 대답을 하셔야 합니다
# - **연도별 게임의 트렌드가 있을까** 라는 질문에 대답을 하셔야 합니다
# - **출고량의 높은 게임에 대한 분석 및 시각화 프로세스**가 포함되어야 합니다
# - **결론적으로 다음 분기에 어떤 게임을 설계해야 하는지를 제시**하셔야 합니다
# - 추가 인사이트

# %% [markdown]
# ##EDA

# %%
df.shape
# Out:
# (16598, 10)

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# Name            object
# Platform        object
# Year           float64
# Genre           object
# Publisher       object
# NA_Sales        object
# EU_Sales        object
# JP_Sales        object
# Other_Sales     object
# dtype: object

# %%
df.sample(10)
# Out:
#        Unnamed: 0                                             Name Platform  \
# 5988         5989         Jimmie Johnson's Anything With an Engine      Wii
# 15253       15254                                    NBA Live 2005      PS2
# 13037       13038                                    Vampire Night      PS2
# 11765       11766                                            Skate     X360
# 4901         4902                         Chaotic: Shadow Warriors     X360
# 14044       14045                              Colin McRae Rally 3      PS2
# 8751         8752  Final Fantasy Crystal Chronicles: Ring of Fates       DS
# 9250         9251                                       Madagascar      GBA
# 15459       15460                            Gekka Ryouran Romance      PSP
# 7278         7279                           Divinity: Original Sin     XOne
#
#          Year         Genre                     Publisher NA_Sales EU_Sales  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# Name             0
# Platform         0
# Year           271
# Genre           50
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %%
df.describe()
# Out:
#          Unnamed: 0          Year
# count  16598.000000  16327.000000
# mean    8299.500000   1994.242543
# std     4791.574219    155.077168
# min        1.000000      0.000000
# 25%     4150.250000   2003.000000
# 50%     8299.500000   2007.000000
# 75%    12448.750000   2010.000000
# max    16598.000000   2020.000000

# %% [markdown]
# ###EDA-Year

# %%
df.Year.dtype
# Out:
# dtype('float64')

# %%
# Year missing value
df[df.Year.isnull()]
# Out:
#        Unnamed: 0                                         Name Platform  Year  \
# 31             32                                    Rock Band     X360   NaN
# 109           110   Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii   NaN
# 273           274  Jewel Link Chronicles: Mountains of Madness       DS   NaN
# 358           359           Majesty 2: The Fantasy Kingdom Sim     X360   NaN
# 430           431                                   Famista 64      N64   NaN
# ...           ...                                          ...      ...   ...
# 16240       16241                                Freaky Flyers       GC   NaN
# 16275       16276                               Space Invaders     2600   NaN
# 16278       16279                                Madden NFL 11      Wii   NaN
# 16425       16426                               Yoostar on MTV     X360   NaN
# 16432       16433                                  Bejeweled 3     X360   NaN
#
# ...

# %%
df[df.Year.isnull()].shape[0]/df.shape[0]
# Out:
# 0.016327268345583804

# %% [markdown]
# ###EDA-Platform

# %%
df[df.Platform.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %%
df.Platform.unique()
# Out:
# array(['DS', 'Wii', 'PSP', 'PS3', 'PC', 'PS', 'GBA', 'PS4', 'PS2', 'XB',
#        'X360', 'GC', '3DS', '2600', 'SAT', 'GB', 'NES', 'DC', 'N64',
#        'XOne', 'SNES', 'WiiU', 'PSV', 'GEN', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df.Platform.nunique()
# Out:
# 31

# %% [markdown]
# ###EDA-Genre

# %%
df[df.Genre.isnull()].shape[0]
# Out:
# 50

# %%
df[df.Genre.isnull()]
# Out:
#        Unnamed: 0                                         Name Platform  \
# 50             51                     Ape Escape: On the Loose      PSP
# 408           409                                  NBA Ballers       XB
# 1328         1329                                   NFL Street       XB
# 1582         1583               SingStar Singalong With Disney      PS2
# 1971         1972                          Pokemon X/Pokemon Y      3DS
# 2043         2044                                NASCAR Racing       PS
# 2497         2498             Jurassic Park III: Island Attack      GBA
# 3353         3354                  The Godfather: Dons Edition      PS3
# 3363         3364                 Ski-Doo Snowmobile Challenge     X360
# 3470         3471           Batman Beyond: Return of the Joker      N64
# 3515         3516     Princess Saver! Eternal Love for My Lady      PS2
# 3932         3933                            MVP Baseball 2004      PS2
# ...

# %%
df.Genre.unique()
# Out:
# array(['Action', 'Adventure', 'Misc', 'Platform', 'Sports', 'Simulation',
#        'Racing', 'Role-Playing', 'Puzzle', 'Strategy', 'Fighting',
#        'Shooter', nan], dtype=object)

# %%
df[df.Genre == 'Platform']
# Out:
#        Unnamed: 0                                       Name Platform    Year  \
# 4               5  Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# 20             21                     Ty the Tasmanian Tiger      PS2  2002.0
# 25             26                                   Dr. Muto       GC  2002.0
# 28             29                    Famicom Mini: Makaimura      GBA  2004.0
# 34             35            Mega Man Anniversary Collection      PS2  2004.0
# ...           ...                                        ...      ...     ...
# 16531       16532                  New Super Mario Bros. Wii      Wii  2009.0
# 16563       16564                                     Wall-E      Wii  2008.0
# 16578       16579                       Gex: Enter the Gecko       PS  1998.0
# 16579       16580                     Super Ghouls 'n Ghosts      GBA  2002.0
# 16593       16594                    Ice Age 2: The Meltdown       GC  2006.0
#
# ...

# %% [markdown]
# ###EDA-PUblisher

# %%
df[df.Publisher.isnull()]
# Out:
#        Unnamed: 0                                               Name Platform  \
# 272           273                                 UK Truck Simulator       PC
# 1313         1314     All Grown Up!: Game Boy Advance Video Volume 1      GBA
# 1560         1561  Teenage Mutant Ninja Turtles: Game Boy Advance...      GBA
# 1789         1790  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 1879         1880                     Monster Hunter Frontier Online      PS3
# 1961         1962  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 2070         2071                                     World of Tanks     X360
# 2970         2971                               Chou Soujuu Mecha MG       DS
# 3184         3185                       Action Man-Operation Extreme       PS
# 3412         3413                                  Dance with Devils      PSV
# 3533         3534                          B.L.U.E.: Legend of Water       PS
# ...

# %%
df.Publisher.unique()
# Out:
# array(['Destineer', 'Namco Bandai Games', 'Alchemist', 'Zoo Games',
#        'D3Publisher', 'Konami Digital Entertainment', 'Deep Silver',
#        'Tecmo Koei', 'Sega', 'THQ', 'Empire Interactive', 'Ubisoft',
#        'Paradox Interactive', '505 Games', 'Tomy Corporation',
#        'Eidos Interactive', 'Microsoft Game Studios',
#        'Nippon Ichi Software', 'Kalypso Media', 'Electronic Arts',
#        'Sony Computer Entertainment', 'Activision',
#        'Tru Blu Entertainment', 'Warner Bros. Interactive Entertainment',
#        'Midway Games', 'Mindscape', 'Wargaming.net', 'Capcom',
#        'Acclaim Entertainment', 'Unknown', 'Nintendo',
#        'Disney Interactive Studios', 'Crave Entertainment', 'Sunflowers',
#        'Arc System Works', 'Milestone S.r.l', 'Kamui', 'Hudson Soft',
#        'Square Enix', 'Focus Home Interactive', 'Take-Two Interactive',
#        'Game Factory', 'Takara Tomy', 'SquareSoft', 'Global Star',
# ...

# %%
df.Publisher.nunique()
# Out:
# 578

# %% [markdown]
# ###EDA-Sales

# %%
df.sample(15)
# Out:
#        Unnamed: 0                                   Name Platform    Year  \
# 10544       10545                               Catwoman       GC  2004.0
# 11459       11460                                    Rio       DS  2011.0
# 128           129              Rozen Maiden: Gebetgarten      PS2  2007.0
# 4246         4247                               ArmA III       PC  2013.0
# 11662       11663                       Dragoneer's Aria      PSP  2007.0
# 1198         1199                     NCAA Football 2003       XB  2002.0
# 15903       15904             Yu-Gi-Oh! 5D's Tag Force 6      PSP  2011.0
# 13951       13952                     Top Gun: Hard Lock     X360  2012.0
# 8769         8770              Street Fighter Collection      SAT  1996.0
# 5863         5864                     Samurai Warriors 2      PS2  2006.0
# 10609       10610  Disney's Story Studio: Disney's Mulan       PS  1999.0
# 395           396       The Settlers II 10th Anniversary       PC  2006.0
# ...

# %%
# K, M 있는 것만 꺼내보자
# foo[foo.b.str.contains('oo', regex= True, na=False)]

# df.columns
# 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'

df[df.NA_Sales.str.contains('M',regex=True, na=False)]
# Out:
#        Unnamed: 0                                        Name Platform  \
# 447           448                  Medal of Honor: Warfighter     X360
# 458           459                                     F1 2010      PS3
# 577           578                               Mario Kart 64      N64
# 625           626                                  The Hobbit      GBA
# 672           673  Star Wars The Clone Wars: Lightsaber Duels      Wii
# ...           ...                                         ...      ...
# 15986       15987                 Juiced 2: Hot Import Nights       PC
# 16152       16153                       Taiko no Tatsujin Wii      Wii
# 16169       16170                    Medal of Honor: Airborne     X360
# 16408       16409               NASCAR 06: Total Team Control      PS2
# 16482       16483            Super Robot Taisen F Kanketsuhen      SAT
#
#          Year     Genre           Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %%
df[df.NA_Sales.str.contains('K',regex=True, na=False)]
# Out:
#        Unnamed: 0                                            Name Platform  \
# 10             11                                     Ford Racing       PS
# 45             46                    Resident Evil: Revelations 2      PS3
# 145           146                              TOCA Race Driver 3       PC
# 878           879  Tears to Tiara Anecdotes: The Secret of Avalon      PS3
# 1086         1087                       Pro Evolution Soccer 2014      3DS
# ...           ...                                             ...      ...
# 15647       15648                       Championship Manager 2010       PC
# 16194       16195                            Vin Diesel: Wheelman      PS3
# 16330       16331                         Midway Arcade Treasures      PS2
# 16492       16493                                   Mortal Kombat      PSV
# 16578       16579                            Gex: Enter the Gecko       PS
#
# ...

# %%
df[df.iloc[:,-1].str.contains('M',regex=True, na=False)]
# Out:
#        Unnamed: 0                                               Name Platform  \
# 64             65                                    SD Gundam Force      GBA
# 73             74                       Teenage Mutant Ninja Turtles       XB
# 209           210              Harry Potter and the Sorcerer's Stone       XB
# 220           221          Dragon Quest IV: Michibikareshi Monotachi       PS
# 243           244                 Seaman 2: Peking Genjin Ikusei Kit      PS2
# ...           ...                                                ...      ...
# 15998       15999                          Pro Yakyuu Family Stadium      NES
# 16036       16037                                      Point Blank 2       PS
# 16074       16075                     The Black Eyed Peas Experience      Wii
# 16141       16142  World Championship Poker: Featuring Howard Led...      PS2
# 16412       16413  Yu-Gi-Oh! Ultimate Masters: World Championship...      GBA
#
# ...

# %% [markdown]
# ####Codes to test 🙅

# %%
df_test = df.copy()

# %% [markdown]
# #####<font color = 'grey'>not working</font>

# %% [markdown]
# Delete non-number in characters using regular expression
#
# `re.sub(pattern, new, string)`<br>
# string에서 pattern에 해당하는 부분을 new로 대체하라는 의미 <br>
# (replace 'pattern' with 'new' in 'string')
#
# ```python
# # 함수를 만들어 구현
# import re
#
# def convert(phone_number):
#   phone_number = re.sub(r"/D","", phone_number)[-8:]   #\D = [^0-9] \d = [0-9]
#   final_number = '010' + '-' + phone_number[:4] + '-' + phone_number[-4:]
#   return final_number
#
# # 만든 함수를 .apply() 함수를 이용해 적용
# patients_clean.전화번호 = patients_clean.전화번호.apply(convert)
# ```
#
# [pandas.DataFrame.astype](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html)
# - DataFrame.astype(dtype, copy=True, errors='raise')
# - Cast a pandas object to a specified dtype dtype. <pr>
#
# [Column에서 astype을 쓰는 방법](https://cosmosproject.tistory.com/123)
# ```python
# df_test.loc[:, ['col1']] = df_test.loc[:, ['col1']].astype('str')
# ```

# %%
import re

def convert(sales_figure):
  sales_figure = re.sub(r"\D","",sales_figure)
  # sales_figure = sales_figure.astype(float)
  return sales_figure

# %% [markdown]
# [range(start, stop, step)](https://www.geeksforgeeks.org/python-range-function/)
#
# - start: integer starting from which the sequence of integers is to be returned
# - stop: integer before which the sequence of integers is to be returned. The range of integers ends at stop – 1.
# - step: integer value which determines the increment between each integer in the sequence

# %%
for i in range(1,5,1):
  df_test.iloc[:,-i] = df_test.iloc[:,-i].apply(convert)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-3a0ebbab6f71> in <module>
#       1 for i in range(1,5,1):
# ----> 2   df_test.iloc[:,-i] = df_test.iloc[:,-i].apply(convert)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
# ...

# %%
for i in range(1,5,1):
  df_test.iloc[:,-i] = df_test.iloc[:,-i].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-e94f0f4b098c> in <module>
#       1 for i in range(1,5,1):
# ----> 2   df_test.iloc[:,-i] = df_test.iloc[:,-i].astype(float)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %% [markdown]
# #####**working**

# %%
import re

def convert(sales_figure):
  sales_figure = re.sub(r"\D","",sales_figure)

  return sales_figure

# %%
df_test.iloc[:,-1]=df_test.iloc[:,-1].apply(convert)

# %%
df_test.iloc[[64]]
# Out:
#     Unnamed: 0             Name Platform    Year    Genre           Publisher  \
# 64          65  SD Gundam Force      GBA  2004.0  Shooter  Namco Bandai Games
#
#    NA_Sales EU_Sales JP_Sales Other_Sales
# 64     0.01        0        0          0M

# %%
for i in range(1,5,1):
  df_test.iloc[:,-i] = df_test.iloc[:,-i].apply(convert)

# %% [markdown]
# #####<font color = 'grey'>not working</font>

# %%
index_list = df[df.NA_Sales.str.contains('M',regex=True, na=False) | df.EU_Sales.str.contains('M',regex=True, na=False) | \
                df.JP_Sales.str.contains('M',regex=True, na=False) | df.Other_Sales.str.contains('M',regex=True, na=False) ].index.tolist()
index_list

# %%
df_test[[index_list,:]]
# Out:
#   File "<ipython-input-112-3517ee9635b9>", line 1
#     df_test[[index_list,:]]
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #####working

# %% [markdown]
# **First of all, `search` for the rows to be fixed. This process results in a list of True/False**
#
# ```python
# import re
#
# def has_errors(inputString):
#   return bool(re.search('[_,!,.,\d+]', inputString))
#
#   # (설명)re.search --- inputString arguments에 _ ! . \d+ 숫자(한 개 이상 +) 찾으면
#   # (설명) bool --- True/False로 나온다
# ```
#
# ```python
# # 이름에 섞여 있는 오류 데이터를 확인
# error_condition = patients_clean.이름.apply(has_errors)
# error_names = patients_clean[error_condition]
# error_names
#
#  # (설명) error_condition에 어떤 조건을 넣고, 그 조건이 맞는 데이터프레임을 error_name으로 불러옴
#  ```
#
#
# **Second, `replace` characters in values of the rows that has been searched in the first step**
# ```python
# # 코드가 정확하게 오류를 제거하는지 확인
# error_names.이름 = error_names.이름.str.replace('[_,!,.,\d+]','')
# error_names
#
# # (설명) str.replace()는 시리즈에서 _,!,.,\d+를 없애는 것으로 대체함
# ```
# **Finally, apply the same `str.replace` method to the target DataFrame**
# ```python
# # 제거된 것을 확인하였으면, 환자데이터 이름 컬럼에 적용
# patients_clean.이름 = patients_clean.이름.str.replace('[_,!,.,\d+]','')
# ```

# %%
import re

def has_errors(inputString):
  return bool(re.search('[M,K]',inputString))

# %%
# call list of boolean that indicates number(False) or non-number(True)
not_num_list_NA = df_test.NA_Sales.apply(has_errors)
not_num_list_EU = df_test.EU_Sales.apply(has_errors)
not_num_list_JP = df_test.JP_Sales.apply(has_errors)
not_num_list_Other = df_test.Other_Sales.apply(has_errors)

# %%
df_test_figure_err = df_test[not_num_list_NA | not_num_list_EU | not_num_list_JP | not_num_list_Other]
df_test_figure_err
# Out:
#        Unnamed: 0                                   Name Platform    Year  \
# 10             11                            Ford Racing       PS  2001.0
# 36             37              Advance Wars: Dual Strike       DS  2005.0
# 45             46           Resident Evil: Revelations 2      PS3  2015.0
# 64             65                        SD Gundam Force      GBA  2004.0
# 73             74           Teenage Mutant Ninja Turtles       XB  2003.0
# ...           ...                                    ...      ...     ...
# 16525       16526                        Planet Monsters      GBA  2001.0
# 16571       16572                           Koihime Enbu      PS4  2016.0
# 16578       16579                   Gex: Enter the Gecko       PS  1998.0
# 16580       16581  Captain Morgane and the Golden Turtle       DS  2012.0
# 16591       16592                        Madden NFL 2005      PS2  2004.0
#
#            Genre                      Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %% [markdown]
# #####<font color = 'grey'>not working</font>

# %%
test_figure_err_boolean = [not_num_list_NA | not_num_list_EU | not_num_list_JP | not_num_list_Other]
test_figure_err_boolean
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  16593    False
#  16594    False
#  16595    False
#  16596    False
#  16597    False
#  Length: 16598, dtype: bool]

# %%
df_test[test_figure_err_boolean]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-98d06e15599c> in <module>
# ----> 1 df_test[test_figure_err_boolean]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %% [markdown]
# #####**working**

# %%
# df_test_figure_err.iloc[:,-4:-1] = df_test_figure_err.iloc[:,-4:-1].str.replace("[M,K]","")
# DataFrame에선 str 안 돌아가니까, column단위에서 보기 위해서 for문 돌림

for i in range(1,5,1):
  df_test_figure_err.iloc[:,-i] = df_test_figure_err.iloc[:,-i].str.replace("[M,K]","")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %% [markdown]
# [iloc[ ] to choose the last column](https://stackoverflow.com/questions/37512079/python-pandas-why-does-df-iloc-1-values-for-my-training-data-select-till)
#
# Python list slicing syntax states that for a:b it will get a and everything upto but not including b. a: will get a and everything after it. :b will get everything before b but not b. The list index of -1 refers to the last element. :-1 adheres to the same standards as above in that this gets everything before the last element but not the last element. If you want the last element included use :.

# %%
df_test_figure_err.iloc[:,-4:] #마지막 column이 나오려면 -1을 쓰면 그 전까지 나오니까, 아무것도 안 쓰면 된다
# Out:
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 10         480     0.33        0        0.06
# 36         0.3     0.03     0.04        0.03
# 45          60     0.08     0.16        0.03
# 64        0.01        0        0           0
# 73        0.22     0.06        0        0.01
# ...        ...      ...      ...         ...
# 16525     0.01        0        0           0
# 16571        0        0     0.02           0
# 16578      320     0.22        0        0.04
# 16580        0     0.03        0           0
# 16591     4.18     0.26     0.01          80
#
# [785 rows x 4 columns]

# %%
df_test.sample(5)
# Out:
#        Unnamed: 0                                               Name Platform  \
# 3769         3770                    Barbie and the Three Musketeers       DS
# 10336       10337                       Harukanaru Toki no Naka de 6      PSV
# 11749       11750                                Tom Clancy's EndWar      PS3
# 4795         4796  Tim Burton's The Nightmare Before Christmas: O...       XB
# 12722       12723                                     Rayman Origins      3DS
#
#          Year      Genre                   Publisher NA_Sales EU_Sales  \
# 3769   2009.0  Adventure                  Activision     0.12        0
# 10336  2015.0     Action                  Tecmo Koei        0        0
# 11749  2008.0   Strategy                     Ubisoft     0.32     0.22
# 4795   2005.0  Adventure  Disney Interactive Studios     0.06     0.02
# 12722  2012.0   Platform                     Ubisoft     0.06     0.08
#
#       JP_Sales Other_Sales
# 3769         0        0.01
# ...

# %%
import re

def has_errors(inputString):
  return bool(re.search('K',inputString))


for i in range(len(df_test.shape[0])):
  if df_test.NA_Sales[i].apply(has_errors) == True:
    df_test.NA_Sales[i] = df_test.NA_Sales[i].str.replace("K","")
    df_test.NA_Sales[i] = df_test.NA_Sales[i].astype({}'int')


# import re

# def has_errors(inputString):
#   return bool(re.search('K',inputString))

# df_test[df_test.NA_Sales.apply(has_errors) == True]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-182dbea342ac> in <module>
#       5
#       6
# ----> 7 for i in range(len(df_test.shape[0])):
#       8   if df_test.NA_Sales[i].apply(has_errors) == True:
#       9     df_test.NA_Sales[i] = df_test.NA_Sales[i].str.replace("K","")
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# ####Codes to proceed 🙆

# %%
df_clean = df.copy()

# %%
df_clean.sample(5)
# Out:
#        Unnamed: 0                               Name Platform    Year  \
# 10149       10150       Midnight Club 3: DUB Edition       XB  2005.0
# 2891         2892               Zangeki no Reginleiv      Wii  2010.0
# 843           844                 MX vs. ATV Untamed       DS  2007.0
# 10253       10254  Fatal Frame II: Crimson Butterfly      PS2  2003.0
# 11028       11029     Ready 2 Rumble Boxing: Round 2       PS  2000.0
#
#           Genre             Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 10149    Racing  Take-Two Interactive     0.61      0.1        0        0.03
# 2891     Action              Nintendo        0        0     0.11           0
# 843      Racing                   THQ     0.11        0        0        0.01
# 10253    Action               Ubisoft     0.08     0.06        0        0.02
# 11028  Fighting          Midway Games     0.29      0.2        0        0.03

# %% [markdown]
# *Do not drop K, M at the same time because K, M are hinting unit* </br>
# *Instead, drop K and multiply 0.001 at the same time and just drop M*

# %%
# for i in range(1,5,1):
#   df_clean.iloc[:,-i] = df_clean.iloc[:,-i].str.replace("M","")

# for i in range(1,5,1):
#   df_clean.iloc[:,-i] = df_clean.iloc[:,-i].str.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   16598 non-null  int64
#  1   Name         16598 non-null  object
#  2   Platform     16598 non-null  object
#  3   Year         16327 non-null  float64
#  4   Genre        16548 non-null  object
#  5   Publisher    16540 non-null  object
#  6   NA_Sales     16598 non-null  object
#  7   EU_Sales     16598 non-null  object
#  8   JP_Sales     16598 non-null  object
#  9   Other_Sales  16598 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# ###EDA-Duplicated

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %% [markdown]
# ###EDA result
#
# Quality Issue
# - Null: year 271, Genre 50, Publisher 58 🟢
# - Year data type : float to integer, drop 271 null rows (1.6% of raw data) 🟢
# - Sales : K,M, unit alignment ex. 0M, 50K 🟢
# - Genre : drop 50 null rows, dtype to category 🟢
# - Publisher : drop 58 null rows 🟢
# - Unnamed:0  : primary key to index 🟢
#
# Structure Issue
# - Sales : melt into one column 🟢

# %% [markdown]
# ##Wrangling

# %%
df_clean = df.copy()

# %% [markdown]
# ####Wrangling-Genre

# %% [markdown]
# [pandas.DataFrame.dropna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)
# - DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
#   - subset: Labels along other axis to consider, e.g. if you are dropping rows these would be a list of columns to include.

# %%
# Drop rows that are NaN in Genre
df_clean = df_clean.dropna(subset=['Genre'])

# %%
df_clean.shape[0]
# Out:
# 16548

# %%
# Transform data type of Genre into categorical type
df_clean.Genre = df_clean.Genre.astype('category')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_clean.Genre.dtype
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Fighting', 'Misc', 'Platform',
#                   'Puzzle', 'Racing', 'Role-Playing', 'Shooter', 'Simulation',
#                   'Sports', 'Strategy'],
# , ordered=False)

# %% [markdown]
# ###Wrangling-Year

# %%
df_clean.head()
# Out:
#    Unnamed: 0                                            Name Platform  \
# 0           1                    Candace Kane's Candy Factory       DS
# 1           2                                  The Munchables      Wii
# 2           3  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP
# 3           4                Deal or No Deal: Special Edition       DS
# 4           5       Ben 10 Ultimate Alien: Cosmic Destruction      PS3
#
#      Year      Genre           Publisher NA_Sales EU_Sales JP_Sales  \
# 0  2008.0     Action           Destineer     0.04        0        0
# 1  2009.0     Action  Namco Bandai Games     0.17        0        0
# 2  2010.0  Adventure           Alchemist        0        0     0.02
# 3  2010.0       Misc           Zoo Games     0.04        0        0
# 4  2010.0   Platform         D3Publisher     0.12     0.09        0
#
#   Other_Sales
# 0           0
# 1        0.01
# 2           0
# 3           0
# 4        0.04

# %%
# Drop NaN in Year
df_clean = df_clean.dropna(subset=['Year'])

# %%
df_clean.shape
# Out:
# (16277, 10)

# %%
# Change data type of Year into integer
df_clean.Year = df_clean.Year.astype('int')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_clean.Year.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ###Wrangling-Publisher

# %%
df_clean.shape
# Out:
# (16277, 10)

# %%
df_clean = df_clean.dropna(subset=['Publisher'])
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16241 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   16241 non-null  int64
#  1   Name         16241 non-null  object
#  2   Platform     16241 non-null  object
#  3   Year         16241 non-null  int64
#  4   Genre        16241 non-null  category
#  5   Publisher    16241 non-null  object
#  6   NA_Sales     16241 non-null  object
#  7   EU_Sales     16241 non-null  object
#  8   JP_Sales     16241 non-null  object
#  9   Other_Sales  16241 non-null  object
# dtypes: category(1), int64(2), object(7)
# memory usage: 1.3+ MB

# %% [markdown]
# ###Wrangling-Sales

# %%
sales_list = list(df_clean)[-4:]

# %%
df_clean[sales_list].sample(10)
# Out:
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 5680         0     0.04        0           0
# 6732       0.1     0.08     0.07        0.04
# 13402     0.06     0.02        0           0
# 12293        0     0.19        0        0.05
# 12265        0     0.02        0           0
# 10283      0.1     0.01        0        0.01
# 1373      0.76     0.36     0.05        0.18
# 210       0.29     0.02        0           0
# 16238     0.05      0.1        0        0.03
# 10341     0.12     0.03        0        0.01

# %%
import re

def has_units(inputString):
  return bool(re.search('[M,K]', inputString))

# %%
# M, K를 포함하는 rows가 True인 boolean 리스트
Unit_NA = df_clean.NA_Sales.apply(has_units)
Unit_EU = df_clean.EU_Sales.apply(has_units)
Unit_JP = df_clean.JP_Sales.apply(has_units)
Unit_Other = df_clean.Other_Sales.apply(has_units)

# %%
df_clean[Unit_NA | Unit_EU | Unit_JP | Unit_Other].query(' Year == 2011 ').sample(20)
# Out:
#        Unnamed: 0                                           Name Platform  \
# 10274       10275     Phineas and Ferb: Across the 2nd Dimension      PS3
# 7505         7506                               Pac-Man Party 3D      3DS
# 5561         5562                  Meikyuu Cross Blood: Reloaded     X360
# 14250       14251                              Airport Simulator       PC
# 15270       15271        Tales of the World: Radiant Mythology 3      PSP
# 8421         8422                                   Grease Dance      PS3
# 13487       13488                         Dance! It's Your Stage      PS3
# 493           494                             Rise of Nightmares     X360
# 2948         2949                             Army Corps of Hell      PSV
# 2495         2496                                    Bulletstorm     X360
# 16347       16348                            Aladdin Magic Racer      Wii
# 13168       13169                                 Rayman Origins     X360
# ...

# %%
df_clean.loc[[8010, 6929]]
# Out:
#       Unnamed: 0           Name Platform  Year    Genre             Publisher  \
# 8010        8011  Battlefield 3     X360  2011  Shooter       Electronic Arts
# 6929        6930       NBA 2K12      PS3  2011   Sports  Take-Two Interactive
#
#      NA_Sales EU_Sales JP_Sales Other_Sales
# 8010     4.46    2130K     0.06        0.69
# 6929    1610K     0.27     0.05        0.18

# %% [markdown]
# **(결론) 출시한 해(1년)에 팔린 장수로 보자**
# > Year : 출시년도</br>
# > K, M 안 붙어있는 수치 : million </br>
# > [Battlefield 3 copies sold till Dec 2011](https://www.eurogamer.net/battlefield-3-sales-hit-8-million) </br>
# Battlefield 3 has now sold eight million copies since launch, publisher EA has revealed.</br>
# Data -> 7.34M</br>
# > [NBA 2K12 copies sold till Feb 2012](https://www.gamespot.com/articles/red-dead-redemption-sells-13m-nba-2k12-hits-4m/1100-6349683/) </br>
# NBA 2K12 sales have reached 4 million units </br>
# Data -> 2,110K

# %%
df_clean_MK = df_clean[Unit_NA | Unit_EU | Unit_JP | Unit_Other]

# %%
# M은 떼어내기

df_clean.NA_Sales = df_clean.NA_Sales.str.replace('M',"")
df_clean.EU_Sales = df_clean.EU_Sales.str.replace('M',"")
df_clean.JP_Sales = df_clean.JP_Sales.str.replace('M',"")
df_clean.Other_Sales = df_clean.Other_Sales.str.replace('M',"")

# %%
df_clean[df_clean.index.isin(df_clean_MK.index)].sample(10)
# Out:
#        Unnamed: 0                                               Name Platform  \
# 9472         9473                                      Darksiders II     XOne
# 642           643            LEGO Star Wars II: The Original Trilogy       GC
# 15385       15386                         Thrillville: Off the Rails     X360
# 15808       15809                  Final Fantasy XIV: A Realm Reborn       PC
# 8992         8993  Virtua Fighter CG Portrait Series Vol.1: Sarah...      SAT
# 16482       16483                   Super Robot Taisen F Kanketsuhen      SAT
# 1650         1651                        Test Drive: Ferrari Legends      PS3
# 8010         8011                                      Battlefield 3     X360
# 12158       12159                              Front Mission Evolved     X360
# 10389       10390                                       Lost Horizon       PC
#
#        Year         Genre        Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %%
import re
import math

for i, sales in enumerate(df_clean.NA_Sales):
  if bool(re.search('K', sales)):
    df_clean.iloc[i,6] = re.sub(r"\D","",df_clean.iloc[i,6])
    df_clean.iloc[i,6] = float(df_clean.iloc[i,6])
    df_clean.iloc[i,6] = df_clean.iloc[i,6]*0.001

for i, sales in enumerate(df_clean.EU_Sales):
  if bool(re.search('K', sales)):
    df_clean.iloc[i,7] = re.sub(r"\D","",df_clean.iloc[i,7])
    df_clean.iloc[i,7] = float(df_clean.iloc[i,7])
    df_clean.iloc[i,7] = df_clean.iloc[i,7]*0.001

for i, sales in enumerate(df_clean.JP_Sales):
  if bool(re.search('K', sales)):
    df_clean.iloc[i,8] = re.sub(r"\D","",df_clean.iloc[i,8])
    df_clean.iloc[i,8]= float(df_clean.iloc[i,8])
    df_clean.iloc[i,8] = df_clean.iloc[i,8]*0.001

for i, sales in enumerate(df_clean.Other_Sales):
  if bool(re.search('K', sales)):
    df_clean.iloc[i,9] = re.sub(r"\D","",df_clean.iloc[i,9])
    df_clean.iloc[i,9] = float(df_clean.iloc[i,9])
    df_clean.iloc[i,9] = df_clean.iloc[i,9]*0.001

# .extract, .astype 쓸 때, 앞에 iloc[i,6] 다음에 붙으면 str 특징이 없어서? 안 돌아간다. 왜 그러냐.

# %%
df_clean[df_clean.index.isin(df_clean_MK.index)].sample(10)
# Out:
#        Unnamed: 0                                 Name Platform  Year  \
# 13874       13875                         Classic Road       PS  1995
# 10342       10343                              NBA 2K6       XB  2005
# 13341       13342                          NASCAR Heat       PS  2000
# 8276         8277   Olympic Summer Games: Atlanta 1996       PS  1996
# 1895         1896               Heart no Kuni no Alice      PSP  2009
# 8589         8590  The Walking Dead: Survival Instinct     WiiU  2013
# 9244         9245                         Afro Samurai      PS3  2009
# 5583         5584                      Digimon World 2       PS  2000
# 3768         3769                              DaGeDar       DS  2011
# 16157       16158                        The Suffering      PS2  2004
#
#               Genre               Publisher NA_Sales EU_Sales JP_Sales  \
# 13874        Sports      Victor Interactive        0        0     0.07
# ...

# %%
df_clean.loc[[8827]]
# Out:
#       Unnamed: 0            Name Platform  Year     Genre Publisher NA_Sales  \
# 8827        8828  Arcana Heart 3     X360  2011  Fighting     PQube        0
#
#      EU_Sales JP_Sales Other_Sales
# 8827     0.03     0.02           0

# %% [markdown]
# ###Wrangling-Unnamed :0

# %%
df_clean.sample(10)
# Out:
#        Unnamed: 0                                          Name Platform  \
# 11848       11849         Busou Renkin: Youkoso Papillon Park e      PS2
# 6030         6031                   Chevrolet Camaro: Wild Ride       DS
# 5376         5377                  Star Wars: Republic Commando       XB
# 2389         2390  Call of Duty: Modern Warfare: Reflex Edition      Wii
# 8309         8310           WRC 5: FIA World Rally Championship     XOne
# 10442       10443                         From Russia With Love      PS2
# 3789         3790            Ed, Edd n Eddy: The Mis-Edventures       GC
# 6066         6067                  Dexter's Lab Chess Challenge      GBA
# 1273         1274                             Star Fox: Assault       GC
# 2971         2972                            Namco Museum Vol.3       PS
#
#        Year     Genre                    Publisher NA_Sales EU_Sales JP_Sales  \
# 11848  2007    Action        Marvelous Interactive        0        0     0.02
# ...

# %%
df_clean.tail()
# Out:
#        Unnamed: 0                         Name Platform  Year     Genre  \
# 16593       16594      Ice Age 2: The Meltdown       GC  2006  Platform
# 16594       16595  Rainbow Islands: Revolution      PSP  2005    Action
# 16595       16596                     NBA 2K16      PS3  2015    Sports
# 16596       16597  Toukiden: The Age of Demons      PSV  2013    Action
# 16597       16598     The King of Fighters '95       PS  1996  Fighting
#
#                          Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 16593                Vivendi Games     0.15     0.04        0        0.01
# 16594            Rising Star Games     0.01        0        0           0
# 16595         Take-Two Interactive     0.44     0.19     0.03        0.13
# 16596                   Tecmo Koei     0.05     0.05     0.25        0.03
# 16597  Sony Computer Entertainment        0        0     0.16        0.01

# %%
df_clean.shape
# Out:
# (16241, 10)

# %% [markdown]
# [pandas.DataFrame.set_index](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html)
# - Set the DataFrame index using existing columns.
# - DataFrame.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)
#   ```python
#   df.set_index('month')
#         year  sale
#   month
#   1      2012    55
#   4      2014    40
#   7      2013    84
#   10     2014    31
#   ```

# %%
df_clean.set_index('Unnamed: 0', inplace=True)
df_clean
# Out:
#                                                       Name Platform  Year  \
# Unnamed: 0
# 1                             Candace Kane's Candy Factory       DS  2008
# 2                                           The Munchables      Wii  2009
# 3           Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010
# 4                         Deal or No Deal: Special Edition       DS  2010
# 5                Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010
# ...                                                    ...      ...   ...
# 16594                              Ice Age 2: The Meltdown       GC  2006
# 16595                          Rainbow Islands: Revolution      PSP  2005
# 16596                                             NBA 2K16      PS3  2015
# 16597                          Toukiden: The Age of Demons      PSV  2013
# 16598                             The King of Fighters '95       PS  1996
#
# ...

# %% [markdown]
# [How to Rename Columns in Pandas (With Examples)](https://www.statology.org/pandas-rename-columns/)
# - Rename Specific Columns
# ```python
# df.rename(columns = {'old_col1':'new_col1', 'old_col2':'new_col2'}, inplace = True)
# ```
#
# [How to rename the index of a Pandas DataFrame in Python](https://www.adamsmith.haus/python/answers/how-to-rename-the-index-of-a-pandas-dataframe-in-python)
#   ```python
#   df = pd.DataFrame([[1, 2], [3, 4]], columns = list("ab"))
#   df = df.set_index("a")
#
#   df.index.names = ["index"]
#   ```

# %%
df_clean.index.names = ["Game_Key"]

# %%
df_clean.head()
# Out:
#                                                     Name Platform  Year  \
# Game_Key
# 1                           Candace Kane's Candy Factory       DS  2008
# 2                                         The Munchables      Wii  2009
# 3         Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010
# 4                       Deal or No Deal: Special Edition       DS  2010
# 5              Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010
#
#               Genre           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# Game_Key
# 1            Action           Destineer     0.04        0        0           0
# 2            Action  Namco Bandai Games     0.17        0        0        0.01
# 3         Adventure           Alchemist        0        0     0.02           0
# 4              Misc           Zoo Games     0.04        0        0           0
# 5          Platform         D3Publisher     0.12     0.09        0        0.04

# %% [markdown]
# ###Wrangling-Sales structure

# %%
id_vars = list(df_clean)[0:5]
id_vars
# Out:
# ['Name', 'Platform', 'Year', 'Genre', 'Publisher']

# %%
df_clean = pd.melt(df_clean, id_vars=id_vars, var_name='Region', value_name='Sales')

# %%
df_clean
# Out:
#                                                  Name Platform  Year  \
# 0                        Candace Kane's Candy Factory       DS  2008
# 1                                      The Munchables      Wii  2009
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010
# 3                    Deal or No Deal: Special Edition       DS  2010
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010
# ...                                               ...      ...   ...
# 64959                         Ice Age 2: The Meltdown       GC  2006
# 64960                     Rainbow Islands: Revolution      PSP  2005
# 64961                                        NBA 2K16      PS3  2015
# 64962                     Toukiden: The Age of Demons      PSV  2013
# 64963                        The King of Fighters '95       PS  1996
#
#            Genre                    Publisher       Region Sales
# 0         Action                    Destineer     NA_Sales  0.04
# ...

# %%
# Region 이름 정리
df_clean.Region = df_clean.Region.str.replace('_Sales','')
df_clean
# Out:
#                                                  Name Platform  Year  \
# 0                        Candace Kane's Candy Factory       DS  2008
# 1                                      The Munchables      Wii  2009
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010
# 3                    Deal or No Deal: Special Edition       DS  2010
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010
# ...                                               ...      ...   ...
# 64959                         Ice Age 2: The Meltdown       GC  2006
# 64960                     Rainbow Islands: Revolution      PSP  2005
# 64961                                        NBA 2K16      PS3  2015
# 64962                     Toukiden: The Age of Demons      PSV  2013
# 64963                        The King of Fighters '95       PS  1996
#
#            Genre                    Publisher Region Sales
# 0         Action                    Destineer     NA  0.04
# ...

# %% [markdown]
# ###Wrangling-Sales Data type

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64964 entries, 0 to 64963
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       64964 non-null  object
#  1   Platform   64964 non-null  object
#  2   Year       64964 non-null  int64
#  3   Genre      64964 non-null  category
#  4   Publisher  64964 non-null  object
#  5   Region     64964 non-null  object
#  6   Sales      64964 non-null  object
# dtypes: category(1), int64(1), object(5)
# memory usage: 3.0+ MB

# %%
df_clean.Sales = df_clean.Sales.astype('float')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64964 entries, 0 to 64963
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       64964 non-null  object
#  1   Platform   64964 non-null  object
#  2   Year       64964 non-null  int64
#  3   Genre      64964 non-null  category
#  4   Publisher  64964 non-null  object
#  5   Region     64964 non-null  object
#  6   Sales      64964 non-null  float64
# dtypes: category(1), float64(1), int64(1), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# ##To_CSV

# %%
df_clean.to_csv('vgames2_clean.csv',index=False)
